# %%
import os
os.chdir('/student_dropout_prediction_app')
os.getcwd()
# Out:
# 'c:\\student_dropout_prediction_app'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("cleaned_feature_eng_data.csv")
df.head()
# Out:
#   Marital Status                  Application Mode  Application Order  \
# 0         Single      2nd phase—general contingent                  5
# 1         Single  International student (bachelor)                  1
# 2         Single      1st phase—general contingent                  5
# 3         Single      2nd phase—general contingent                  2
# 4        Married                 Over 23 years old                  1
#
#                            Course Name Daytime/Evening Attendance  \
# 0      Animation and Multimedia Design                    Daytime
# 1                              Tourism                    Daytime
# 2                 Communication Design                    Daytime
# 3         Journalism and Communication                    Daytime
# 4  Social Service (evening attendance)                    Evening
#
#   Previous Qualification Nationality            Mother's Qualification  \
# 0    Secondary education  Portuguese           General commerce course
# ...

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='MaritalStatus_Simple', hue='Student Status', palette='Set2')
plt.title("Effect of Marital Status on Student Status")
plt.xlabel("Marital Status")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='PrevQual', hue='Student Status', palette='Set2')
plt.title("Effect of Previous Qualification on Student Status")
plt.xlabel("Previous Qualification")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x='Course_Field', hue='Student Status', palette='Set2')
plt.title("Effect of Course on Student Status")
plt.xlabel("Course")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x='MotherOcc_Simple', hue='Student Status', palette='Set2')
plt.title("Effect of Mother's Occupation on Student Status")
plt.xlabel("Mother's Occupation")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x='FatherOcc_Simple', hue='Student Status', palette='Set2')
plt.title("Effect of Father's Occupation on Student Status")
plt.xlabel("Father's Occupation")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x='ApplicationMode_Simple', hue='Student Status', palette='Set2')
plt.title("Effect of Application Mode on Student Status")
plt.xlabel("Application Mode")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x='Displaced Student', hue='Student Status', palette='Set2')
plt.title("Effect of Displaced Student on Student Status")
plt.xlabel("Displaced Student")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Special Educational Needs', hue='Student Status', palette='Set2')
plt.title("Effect of Special Educational Needs on Student Status")
plt.xlabel("Special Educational Needs")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Is Debtor', hue='Student Status', palette='Set2')
plt.title("Effect of Is Debtor on Student Status")
plt.xlabel("Is Debtor")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Tuition Fees Up-to-Date', hue='Student Status', palette='Set2')
plt.title("Effect of Tuition Fees Up-to-Date on Student Status")
plt.xlabel("Tuition Fees Up-to-Dater")
plt.ylabel("Count of Students")
plt.show()

# %%
gender = pd.crosstab(df['Gender (1=Male, 0=Female)'], df['Student Status'], normalize='index') * 100

plt.figure(figsize=(8,5))
sns.heatmap(gender, annot=True, fmt=".1f", cmap="YlGnBu")
plt.title("Percentage of Student Status per Gender")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Load Category', hue='Student Status', palette='Set2')
plt.title("Effect of Load Category on Student Status")
plt.xlabel("Load Category")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Econ_Disadvantage', hue='Student Status', palette='Set2')
plt.title("Effect of Econ_Disadvantage on Student Status")
plt.xlabel("Econ_Disadvantage")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Scholarship Holder', hue='Student Status', palette='Set2')
plt.title("Effect of Scholarship Holder on Student Status")
plt.xlabel("Scholarship Holder")
plt.ylabel("Count of Students")
plt.show()

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.barplot(data=df, x='Student Status', y='Pass Rate (1st Sem)', palette='Set2')
plt.title('Pass Rate (1st Sem) vs Student Status')

plt.subplot(1,2,2)
sns.barplot(data=df, x='Student Status', y='Pass Rate (2nd Sem)', palette='Set2')
plt.title('Pass Rate (2nd Sem) vs Student Status')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.barplot(data=df, x='Student Status', y='Grade Difference', palette='Set2')
plt.title('Grade Difference vs Student Status')
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.barplot(data=df, x='Student Status', y='Financial Hardship', palette='Set2')
plt.title('Financial Hardship vs Student Status')
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.barplot(data=df, x='Student Status', y='Age at Enrollment', palette='Set2')
plt.title('Age at Enrollment vs Student Status')
plt.tight_layout()
plt.show()
